# %% [markdown]
# # Type U: unit, duplex

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib 
matplotlib.rcParams["figure.figsize"] = (20,10)
# Out:
# C:\Users\tomde\AppData\Local\Temp\ipykernel_16228\3364595668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df1 = pd.read_csv('utype.csv')
df1.head()
# Out:
#          Suburb  Rooms Type    Price  Distance  Bedroom2  Bathroom  Car  \
# 0    Abbotsford      3    u  1090000       2.5         3         2  2.0
# 1  Airport West      2    u   500000      13.5         2         1  1.0
# 2  Airport West      2    u   515000      13.5         2         1  1.0
# 3  Airport West      2    u   530000      13.5         2         1  1.0
# 4  Airport West      3    u   752000      13.5         3         1  1.0
#
#    Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  PricePerSqFt
# 0      4290          27.0       1998   -37.8078    144.9965    254.079254
# 1       168          86.0       2011   -37.7215    144.8864   2976.190476
# 2       141          73.0       2013   -37.7298    144.8883   3652.482270
# 3       120          94.0       2012   -37.7234    144.8792   4416.666667
# 4       265         130.0       1993   -37.7302    144.8855   2837.735849

# %% [markdown]
# ## Data cleaning
# ### BuildingArea to Landsize ratio

# %%
df1.shape
# Out:
# (1388, 14)

# %% [markdown]
# #### Building area cannot be smaller than 0, so that would need to be removed

# %%
df1 = df1[df1['BuildingArea'] <= df1['Landsize']]
df1.shape
# Out:
# (1252, 14)

# %% [markdown]
# #### Remove building area smaller than 1/4 of land size in python

# %%
df2 = df1[df1['BuildingArea'] >= df1['Landsize'] / 4]
df2.shape
# Out:
# (696, 14)

# %%
df2.head()
# Out:
#          Suburb  Rooms Type   Price  Distance  Bedroom2  Bathroom  Car  \
# 1  Airport West      2    u  500000      13.5         2         1  1.0
# 2  Airport West      2    u  515000      13.5         2         1  1.0
# 3  Airport West      2    u  530000      13.5         2         1  1.0
# 4  Airport West      3    u  752000      13.5         3         1  1.0
# 5  Airport West      2    u  440000      13.5         2         1  1.0
#
#    Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  PricePerSqFt
# 1       168      86.00000       2011   -37.7215    144.8864   2976.190476
# 2       141      73.00000       2013   -37.7298    144.8883   3652.482270
# 3       120      94.00000       2012   -37.7234    144.8792   4416.666667
# 4       265     130.00000       1993   -37.7302    144.8855   2837.735849
# 5       192     151.96765       1964   -37.7177    144.8787   2291.666667

# %% [markdown]
# ### Remove using std and mean for PricePerSqFT

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('Suburb'):
        m = np.mean(subdf.PricePerSqFt)
        st = np.std(subdf.PricePerSqFt)
        reduced_df = subdf[(subdf.PricePerSqFt>(m-st)) & (subdf.PricePerSqFt<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out

# %%
df2 = remove_pps_outliers(df2)
df2.shape
# Out:
# (418, 14)

# %% [markdown]
# ### Remove features that is 3z away

# %%
column = ['Landsize','BuildingArea']

for col in column:
    df2['zscore'] = (df2[col] - df2[col].mean()) / df2[col].std()
    df2 = df2[(df2['zscore'] > -3) & (df2['zscore'] < 3)]
    
df3 = df2.drop('zscore', axis=1)

# %%
df3.shape
# Out:
# (408, 14)

# %%
df3 = df3.drop(['Rooms'], axis='columns')

# %%
df3.head()
# Out:
#          Suburb Type   Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0  Airport West    u  500000      13.5         2         1  1.0       168
# 1  Airport West    u  515000      13.5         2         1  1.0       141
# 2  Airport West    u  752000      13.5         3         1  1.0       265
# 3  Airport West    u  462500      13.5         2         1  1.0       164
# 4  Airport West    u  510000      13.5         2         1  1.0       141
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude  PricePerSqFt
# 0          86.0       2011   -37.7215    144.8864   2976.190476
# 1          73.0       2013   -37.7298    144.8883   3652.482270
# 2         130.0       1993   -37.7302    144.8855   2837.735849
# 3         126.2       2003   -37.7218    144.8863   2820.121951
# 4          76.0       1985   -37.7202    144.8797   3617.021277

# %% [markdown]
# ### Encode

# %%
dummies = pd.get_dummies(df3.Suburb)
dummies.head(3)
# Out:
#    Airport West  Albion  Alphington  Altona  Altona North  Ascot Vale  \
# 0          True   False       False   False         False       False
# 1          True   False       False   False         False       False
# 2          True   False       False   False         False       False
#
#    Ashburton  Ashwood  Avondale Heights  Balwyn  ...  Templestowe Lower  \
# 0      False    False             False   False  ...              False
# 1      False    False             False   False  ...              False
# 2      False    False             False   False  ...              False
#
#    Thomastown  Thornbury  Toorak  Viewbank  Wantirna South  Watsonia  \
# 0       False      False   False     False           False     False
# 1       False      False   False     False           False     False
# 2       False      False   False     False           False     False
#
#    Werribee  West Footscray  other
# 0     False           False  False
# 1     False           False  False
# 2     False           False  False
#
# [3 rows x 105 columns]

# %%
df4 = pd.concat([df3,dummies.drop('other',axis='columns')],axis='columns')
df4.head(3)
# Out:
#          Suburb Type   Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0  Airport West    u  500000      13.5         2         1  1.0       168
# 1  Airport West    u  515000      13.5         2         1  1.0       141
# 2  Airport West    u  752000      13.5         3         1  1.0       265
#
#    BuildingArea  YearBuilt  ...  Surrey Hills  Templestowe Lower  Thomastown  \
# 0          86.0       2011  ...         False              False       False
# 1          73.0       2013  ...         False              False       False
# 2         130.0       1993  ...         False              False       False
#
#    Thornbury  Toorak  Viewbank  Wantirna South  Watsonia  Werribee  \
# 0      False   False     False           False     False     False
# 1      False   False     False           False     False     False
# 2      False   False     False           False     False     False
#
#    West Footscray
# 0           False
# 1           False
# 2           False
#
# [3 rows x 117 columns]

# %% [markdown]
# ### Remove properties within the same location where example the price of 3 bedroom is smaller than the price of 2 bedroom.

# %%
df4.head(2)
# Out:
#          Suburb Type   Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0  Airport West    u  500000      13.5         2         1  1.0       168
# 1  Airport West    u  515000      13.5         2         1  1.0       141
#
#    BuildingArea  YearBuilt  ...  Surrey Hills  Templestowe Lower  Thomastown  \
# 0          86.0       2011  ...         False              False       False
# 1          73.0       2013  ...         False              False       False
#
#    Thornbury  Toorak  Viewbank  Wantirna South  Watsonia  Werribee  \
# 0      False   False     False           False     False     False
# 1      False   False     False           False     False     False
#
#    West Footscray
# 0           False
# 1           False
#
# [2 rows x 117 columns]

# %%
df4.Suburb.value_counts()
# Out:
# Suburb
# Reservoir         30
# other             21
# Essendon          16
# Bentleigh East    16
# Surrey Hills      13
#                   ..
# Ashburton          1
# Doncaster East     1
# Altona North       1
# Maidstone          1
# Kingsbury          1
# Name: count, Length: 105, dtype: int64

# %%
def plot_scatter_chart(df,Suburb):
    bhk2 = df[(df.Suburb==Suburb) & (df.Bedroom2==2)]
    bhk3 = df[(df.Suburb==Suburb) & (df.Bedroom2==3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.Landsize,bhk2.Price,color='blue',label='2 bedroom', s=50)
    plt.scatter(bhk3.Landsize,bhk3.Price,marker='+', color='green',label='3 bedroom', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price")
    plt.title(Suburb)
    plt.legend()

# %%
plot_scatter_chart(df4,"Pascoe Vale")

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('Suburb'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('Bedroom2'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.PricePerSqFt),
                'std': np.std(bhk_df.PricePerSqFt),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('Bedroom2'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.PricePerSqFt<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')

# %%
df5 = remove_bhk_outliers(df4)
df5.shape
# Out:
# (377, 117)

# %%
plot_scatter_chart(df5,"Pascoe Vale")

# %%
df5.head()
# Out:
#          Suburb Type   Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0  Airport West    u  500000      13.5         2         1  1.0       168
# 1  Airport West    u  515000      13.5         2         1  1.0       141
# 2  Airport West    u  752000      13.5         3         1  1.0       265
# 3  Airport West    u  462500      13.5         2         1  1.0       164
# 4  Airport West    u  510000      13.5         2         1  1.0       141
#
#    BuildingArea  YearBuilt  ...  Surrey Hills  Templestowe Lower  Thomastown  \
# 0          86.0       2011  ...         False              False       False
# 1          73.0       2013  ...         False              False       False
# 2         130.0       1993  ...         False              False       False
# 3         126.2       2003  ...         False              False       False
# 4          76.0       1985  ...         False              False       False
#
#    Thornbury  Toorak  Viewbank  Wantirna South  Watsonia  Werribee  \
# 0      False   False     False           False     False     False
# 1      False   False     False           False     False     False
# 2      False   False     False           False     False     False
# 3      False   False     False           False     False     False
# 4      False   False     False           False     False     False
#
#    West Footscray
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 117 columns]

# %%
# df5 = df4.copy()

# %%
df5 = df5.drop(['Suburb', 'PricePerSqFt'], axis='columns')

# %%
df5.head(3)
# Out:
#   Type   Price  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0    u  500000      13.5         2         1  1.0       168          86.0
# 1    u  515000      13.5         2         1  1.0       141          73.0
# 2    u  752000      13.5         3         1  1.0       265         130.0
#
#    YearBuilt  Lattitude  ...  Surrey Hills  Templestowe Lower  Thomastown  \
# 0       2011   -37.7215  ...         False              False       False
# 1       2013   -37.7298  ...         False              False       False
# 2       1993   -37.7302  ...         False              False       False
#
#    Thornbury  Toorak  Viewbank  Wantirna South  Watsonia  Werribee  \
# 0      False   False     False           False     False     False
# 1      False   False     False           False     False     False
# 2      False   False     False           False     False     False
#
#    West Footscray
# 0           False
# 1           False
# 2           False
#
# [3 rows x 115 columns]

# %%
df5[(df5['Surrey Hills'] == 1) & (df5['Type'] == 'u')]
# Out:
#     Type    Price  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 371    u   745000      11.2         2         1  1.0       161     151.96765
# 373    u   770000      11.2         2         1  1.0       156      70.00000
# 375    u   823000      11.2         2         1  2.0       165      76.80000
# 376    u   899000      11.2         2         1  1.0       226     127.00000
# 377    u   600000      11.2         2         1  2.0       124      80.00000
# 378    u   778500      11.2         2         1  1.0       170      78.00000
# 379    u   825000      11.2         2         1  2.0       180      85.00000
# 380    u   740000      10.2         2         1  2.0       193      80.00000
# 381    u   830000      10.2         2         1  1.0       180     151.96765
# 382    u  1290000      10.2         3         2  1.0       270     151.96765
#
#      YearBuilt  Lattitude  ...  Surrey Hills  Templestowe Lower  Thomastown  \
# 371       1964  -37.83270  ...          True              False       False
# 373       1960  -37.82750  ...          True              False       False
# 375       1970  -37.82200  ...          True              False       False
# 376       1980  -37.83270  ...          True              False       False
# 377       1985  -37.81590  ...          True              False       False
# 378       1960  -37.81860  ...          True              False       False
# 379       1970  -37.83510  ...          True              False       False
# 380       1970  -37.83275  ...          True              False       False
# 381       1964  -37.82794  ...          True              False       False
# 382       1964  -37.83404  ...          True              False       False
#
#      Thornbury  Toorak  Viewbank  Wantirna South  Watsonia  Werribee  \
# 371      False   False     False           False     False     False
# 373      False   False     False           False     False     False
# 375      False   False     False           False     False     False
# 376      False   False     False           False     False     False
# 377      False   False     False           False     False     False
# 378      False   False     False           False     False     False
# 379      False   False     False           False     False     False
# 380      False   False     False           False     False     False
# 381      False   False     False           False     False     False
# 382      False   False     False           False     False     False
#
#      West Footscray
# 371           False
# 373           False
# 375           False
# 376           False
# 377           False
# 378           False
# 379           False
# 380           False
# 381           False
# 382           False
#
# [10 rows x 115 columns]

# %%
df5.shape
# Out:
# (377, 115)

# %% [markdown]
# # Concat

# %%
df_csv = pd.read_csv('final.csv')
df_concat = pd.concat([df5, df_csv])
df_concat.head()
# Out:
#   Type   Price  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0    u  500000      13.5         2         1  1.0       168          86.0
# 1    u  515000      13.5         2         1  1.0       141          73.0
# 2    u  752000      13.5         3         1  1.0       265         130.0
# 3    u  462500      13.5         2         1  1.0       164         126.2
# 4    u  510000      13.5         2         1  1.0       141          76.0
#
#    YearBuilt  Lattitude  ...  Taylors Lakes  Templestowe  Tullamarine  \
# 0       2011   -37.7215  ...            NaN          NaN          NaN
# 1       2013   -37.7298  ...            NaN          NaN          NaN
# 2       1993   -37.7302  ...            NaN          NaN          NaN
# 3       2003   -37.7218  ...            NaN          NaN          NaN
# 4       1985   -37.7202  ...            NaN          NaN          NaN
#
#    Vermont South  Wantirna  West Melbourne  Westmeadows  Wheelers Hill  \
# 0            NaN       NaN             NaN          NaN            NaN
# 1            NaN       NaN             NaN          NaN            NaN
# 2            NaN       NaN             NaN          NaN            NaN
# 3            NaN       NaN             NaN          NaN            NaN
# 4            NaN       NaN             NaN          NaN            NaN
#
#    Windsor  Yallambie
# 0      NaN        NaN
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4      NaN        NaN
#
# [5 rows x 211 columns]

# %%
df_concat = df_concat.fillna(False)
# Out:
# C:\Users\tomde\AppData\Local\Temp\ipykernel_16228\2807897723.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_concat = df_concat.fillna(False)

# %%
df_concat[(df_concat['Surrey Hills'] == 1) & (df_concat['Type'] == 'u')]
# Out:
#     Type    Price  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 371    u   745000      11.2         2         1  1.0       161     151.96765
# 373    u   770000      11.2         2         1  1.0       156      70.00000
# 375    u   823000      11.2         2         1  2.0       165      76.80000
# 376    u   899000      11.2         2         1  1.0       226     127.00000
# 377    u   600000      11.2         2         1  2.0       124      80.00000
# 378    u   778500      11.2         2         1  1.0       170      78.00000
# 379    u   825000      11.2         2         1  2.0       180      85.00000
# 380    u   740000      10.2         2         1  2.0       193      80.00000
# 381    u   830000      10.2         2         1  1.0       180     151.96765
# 382    u  1290000      10.2         3         2  1.0       270     151.96765
#
#      YearBuilt  Lattitude  ...  Taylors Lakes  Templestowe  Tullamarine  \
# 371       1964  -37.83270  ...          False        False        False
# 373       1960  -37.82750  ...          False        False        False
# 375       1970  -37.82200  ...          False        False        False
# 376       1980  -37.83270  ...          False        False        False
# 377       1985  -37.81590  ...          False        False        False
# 378       1960  -37.81860  ...          False        False        False
# 379       1970  -37.83510  ...          False        False        False
# 380       1970  -37.83275  ...          False        False        False
# 381       1964  -37.82794  ...          False        False        False
# 382       1964  -37.83404  ...          False        False        False
#
#      Vermont South  Wantirna  West Melbourne  Westmeadows  Wheelers Hill  \
# 371          False     False           False        False          False
# 373          False     False           False        False          False
# 375          False     False           False        False          False
# 376          False     False           False        False          False
# 377          False     False           False        False          False
# 378          False     False           False        False          False
# 379          False     False           False        False          False
# 380          False     False           False        False          False
# 381          False     False           False        False          False
# 382          False     False           False        False          False
#
#      Windsor  Yallambie
# 371    False      False
# 373    False      False
# 375    False      False
# 376    False      False
# 377    False      False
# 378    False      False
# 379    False      False
# 380    False      False
# 381    False      False
# 382    False      False
#
# [10 rows x 211 columns]

# %%
df_concat.shape
# Out:
# (5432, 211)

# %%
df_concat.to_csv('final.csv', index=False)
